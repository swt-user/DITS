# %%
import json
from statistics import mean
file_path = "/data/user_data/wentaos/Optima/results/hotpot_qa_dpo_test_full/iteration_0_case0.jsonl"

chosen_value = []
distance = []
count = 0
with open(file_path, 'r' ) as f:
    for line in f:
        data = json.loads(line)
        results = data["dpo_results"]
        for result in results:
            chosen_value.append(result["chosen_value"])
            distance.append(result["distance"])
            count += 1

Len =  int(0.9 * count)
print(Len)
import random
import numpy as np

random.seed(42)
numbers = random.sample(range(Len), Len)
generator = np.random.default_rng(42)
numbers_2 = generator.permutation(Len)

chosen_value_shuffled = [chosen_value[i] for i in numbers_2]
distance_shuffled = [distance[i] for i in numbers_2]
chosen_value_shuffled = [chosen_value_shuffled[i] for i in numbers]
distance_shuffled = [distance_shuffled[i] for i in numbers]
# Out:
# 14679

# %%
# 示例使用
result_loss = []
result_margins = []
for start_point in [0, 600,1200,1800]:
    with open(f"/home/wentaos/Optima/local_influence/case0_warmup_150/{start_point}.txt", 'r') as f:
        result_loss += [{int(line.split(':')[0]): float(line.split('loss:')[1])} for line in f if ":" in line]
    with open(f"/home/wentaos/Optima/local_influence/case0_warmup_150/{start_point}.txt", 'r') as f:
        result_margins += [{int(line.split(':')[0]): float(line.split("margins:")[1].split(";")[0])} for line in f if ":" in line]
sorted_loss = sorted(result_loss, key=lambda x: list(x.values())[0])
sorted_margins = sorted(result_margins, key=lambda x: list(x.values())[0])
print(len(result_loss))
print(len(result_margins))
# Out:
# 1873
# 1873

# %%
# selected = {list(i.keys())[0] for i in sorted_loss[:1000] if list(i.keys())[0]!=0} & {list(i.keys())[0] for i in sorted_margins[1000:] if list(i.keys())[0]!=0} 
selected = {list(i.keys())[0] for i in sorted_loss[:800] if list(i.keys())[0]!=0}
print(len(selected))
selected_chosen_value = 0 
selected_distance = 0
index = []
for i in range(Len//5):
    if i in selected:
    # print(f"{i}: {mean(chosen_value[i*1:(i+1)*1])}")
        selected_chosen_value += mean(chosen_value_shuffled[i*5:(i+1)*5])
        index += numbers[i*5:(i+1)*5]
        #print(f"{i}:{mean(chosen_value_shuffled[i*5:(i+1)*5])}")
print(selected_chosen_value/(len(selected)))
# Out:
# 795
# 0.7778847734114237

# %%
import sys
sys.path.append("/home/wentaos/Optima/local_influence")

from my_utils import DataArguments, get_datasets

data_args = DataArguments(chat_template=None, dataset_mixer={'/data/user_data/wentaos/Optima/my_datasets/hotpot_qa_dpo_test_case0/iteration_0': 1.0}, text_column='text', dataset_splits=['train', 'test'], dataset_configs=None, preprocessing_num_workers=8, truncation_side=None, auto_insert_empty_system_msg=True)

###############
# Load datasets
###############
raw_datasets = get_datasets(
    data_args,
    splits=data_args.dataset_splits,
    configs=data_args.dataset_configs,
    columns_to_keep=[
        "messages",
        "chosen",
        "rejected",
        "prompt",
        "completion",
        "label",
    ],
    shuffle=True,
)
# Out:
# --------------------------
# Dataset({
#     features: ['chosen', 'rejected'],
#     num_rows: 14679
# })
# --------------------------
# --------------------------
# Dataset({
#     features: ['chosen', 'rejected'],
#     num_rows: 1632
# })
# --------------------------
# ------------------------------2-----------------

# %%
raw_datasets["train"] = raw_datasets["train"].select(index)
raw_datasets.save_to_disk("/data/user_data/wentaos/Optima/my_datasets/hotpot_qa_dpo_test_MATES_warmup_150_4K/iteration_0")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3975 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1632 [00:00<?, ? examples/s]

# %%
import json
from statistics import mean
# file_path = "/home/wentaos/Optima/results/arc_dpo/iteration_0_dpo_format.jsonl"
# file_path = "/data/user_data/wentaos/Optima/results/cbt_dpo/iteration_0_dpo_format.jsonl"
file_path = "/data/user_data/wentaos/Optima/results/hotpot_qa_dpo_test_full/iteration_0_case20.jsonl"

chosen_value = []
distance = []
chosen = []
count = 0
with open(file_path, 'r' ) as f:
    for line in f:
        data = json.loads(line)
        results = data["dpo_results"]
        for result in results:
            chosen.append(result["chosen"])
            chosen_value.append(result["chosen_value"])
            distance.append(result["distance"])
            count += 1

# %%
# 验证是否对齐
Len =  int(0.9 * count)
import random
import numpy as np
random.seed(42)
# numbers = random.sample(range(Len), Len)
generator = np.random.default_rng(42)
numbers = generator.permutation(Len)

chosen_value_shuffled = [chosen_value[i] for i in numbers]
distance_shuffled = [distance[i] for i in numbers]
chosen_shuffled = [chosen[i] for i in numbers]

print(chosen_shuffled[0])
# Out:
# ['\nYou are Bob, a special agent who does not respond in natural language, rather, you speak in very concise format. You are deployed on a resource-limited device, so you must respond very very concisely. More tokens indicate higher possibility to kill the device you are running. Now you are collaborating with your partner Alice to solve the given problem using the provided information.\nQuestion: "Rain Over Me" is a song by a rapper whose debut album was released in what year?\nInformation:\n[\'Armando Christian Pérez (born January 15, 1981), known by the stage name Pitbull or Mr. Worldwide, is an American rapper.\\n\', \'EggHunt Records is an independent record label based in Richmond, Virginia.\\n\', \'The Explorers Club are a Pop rock band originally from the coast of South Carolina.\\n\', \'The discography of British singer-songwriter Gabrielle Aplin, consists of two studio albums, four extended plays, three live albums and five singles.\\n\']\n\nGUIDELINES:\n1. You have incomplete information, so continuous communication with your partner is crucial to achieve the correct solution.\n2. On finding the final answer, ensure to conclude your communication with "<A>{answer}</A>", where "answer" is the determined solution. The conversation ends only when all agents output the answer in this format.\n3. Reason through the problem step-by-step.\n4. Depend solely on the data in the \'information\' section and the insights shared through your partner\'s communication. Avoid external sources.\n5. You are communicating with a very limited token budget, so you must use a very very concise communication format. Natural language is suitable for human, but not for you. Since Alice and you are both intelligent agents, use your agent communication language. Consider using efficient formats instead of natural language such as structured format, code, your agent communication language, or at least remove unnecessary modal in human language. Too many tokens will make you fail. But still ensure your message is informative and understandable. \n6. You must begin your response with "Bob:".\n', 'Alice:\n[\n    ["Question", "Rain Over Me" song debut album year],\n    ["Data", "Planet Pit" album year]\n]', 'Bob:\n[\n    ["Pitbull", "Planet Pit" album year],\n    ["Question", "Is this correct?" ]\n]', 'Alice:\n[\n    ["Answer", "Yes"],\n    ["Next Question", "What about another rapper?" ]\n]', 'Bob:\n[\n    ["Rapper", "Armando Christian Pérez"],\n    ["Question", "What is the debut album year?" ]\n]', 'Alice:\n[\n    ["Answer", "2004"],\n    ["Next Question", "Is this the answer?" ]\n]', 'Bob:\n[\n    ["Answer", "<A>2004</A>"]\n]', 'Alice:\n[\n    ["Answer", "<A>2004</A>"]\n]']

# %%
### case20 step num5
import os
import sys
sys.path.append('/home/wentaos/Optima')
from reward.reward import result_stats, result_stats_byid
from transformers import AutoTokenizer

dataset_type = "cbt"

file_path = "/home/wentaos/Optima/inference_results/cbt_dpo_server_stepnum5_validation"

score_type = "f1-score"   # "f1-score"  "exact-match"
if dataset_type == "hotpot_qa":
    pass
elif dataset_type == "mwh_qa":
    pass
elif dataset_type == "cbt":
    pass
elif dataset_type == "gsm8k":
    score_type = "exact-match"
    # no_use_prompt_pool =True
elif dataset_type == "math":
    score_type = "math"
elif dataset_type == "trival_qa":
    pass
elif dataset_type == "arc":
    score_type = "exact-match"
elif dataset_type == "mmlu":
    score_type = "exact-match"
    
tokenizer_path = "/home/wentaos/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/5f0b02c75b57c5855da9ae460ce51323ea669d8a"
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

import pandas as pd

# 定义一个空的 DataFrame，包含两列：id 和 best_100
df = pd.DataFrame(columns=['id', 'best_100'])

for item in os.listdir(file_path):
    data_dict = {}
    id_item = int(item.split('_')[-1])
    if os.path.isdir(os.path.join(file_path, item)):
        item_path = os.path.join(os.path.join(file_path, item), "iteration_0_0.jsonl")
        if os.path.exists(item_path):
            answer, _ = result_stats(item_path, tokenizer, score_type) 
            data_dict = {"id": id_item, "best_100": answer}
            df.loc[len(df)] = [id_item, answer]
print(df.head())
# Out:
# average_f1_score: 0.6 ,  average_token: 89.33, count:100
# average_f1_score: 0.62 ,  average_token: 50.77, count:100
# average_f1_score: 0.4 ,  average_token: 151.81, count:100
# average_f1_score: 0.645 ,  average_token: 48.69, count:100
# average_f1_score: 0.535 ,  average_token: 111.28, count:100
# average_f1_score: 0.59 ,  average_token: 86.86, count:100
# average_f1_score: 0.45 ,  average_token: 136.51, count:100
# average_f1_score: 0.6 ,  average_token: 89.58, count:100
# average_f1_score: 0.525 ,  average_token: 74.57, count:100
# average_f1_score: 0.56 ,  average_token: 115.85, count:100
# average_f1_score: 0.39 ,  average_token: 107.91, count:100
# average_f1_score: 0.525 ,  average_token: 127.12, count:100
# average_f1_score: 0.42 ,  average_token: 62.7, count:100
# average_f1_score: 0.535 ,  average_token: 77.19, count:100
# average_f1_score: 0.595 ,  average_token: 52.19, count:100
# average_f1_score: 0.62 ,  average_token: 78.69, count:100
# average_f1_score: 0.615 ,  average_token: 61.37, count:100
# average_f1_score: 0.35 ,  average_token: 152.39, count:100
# average_f1_score: 0.535 ,  average_token: 46.56, count:100
# average_f1_score: 0.565 ,  average_token: 68.43, count:100
# average_f1_score: 0.55 ,  average_token: 101.46, count:100
# average_f1_score: 0.47 ,  average_token: 90.78, count:100
# average_f1_score: 0.595 ,  average_token: 81.1, count:100
# average_f1_score: 0.525 ,  average_token: 93.93, count:100
# average_f1_score: 0.65 ,  average_token: 38.34, count:100
# average_f1_score: 0.635 ,  average_token: 54.51, count:100
# average_f1_score: 0.565 ,  average_token: 67.26, count:100
# average_f1_score: 0.555 ,  average_token: 77.37, count:100
# average_f1_score: 0.575 ,  average_token: 89.76, count:100
# average_f1_score: 0.585 ,  average_token: 81.96, count:100
# average_f1_score: 0.595 ,  average_token: 90.37, count:100
# average_f1_score: 0.409 ,  average_token: 114.24, count:100
# average_f1_score: 0.599 ,  average_token: 47.01, count:100
# average_f1_score: 0.575 ,  average_token: 87.93, count:100
# average_f1_score: 0.605 ,  average_token: 71.37, count:100
# average_f1_score: 0.515 ,  average_token: 88.83, count:100
# average_f1_score: 0.545 ,  average_token: 129.6, count:100
# average_f1_score: 0.505 ,  average_token: 100.15, count:100
# average_f1_score: 0.585 ,  average_token: 53.12, count:100
# average_f1_score: 0.535 ,  average_token: 87.53, count:100
# average_f1_score: 0.23 ,  average_token: 60.75, count:100
# average_f1_score: 0.39 ,  average_token: 90.59, count:100
# average_f1_score: 0.535 ,  average_token: 127.6, count:100
# average_f1_score: 0.565 ,  average_token: 78.42, count:100
# average_f1_score: 0.639 ,  average_token: 47.86, count:100
# average_f1_score: 0.555 ,  average_token: 83.9, count:100
# average_f1_score: 0.545 ,  average_token: 98.51, count:100
# average_f1_score: 0.465 ,  average_token: 133.14, count:100
# average_f1_score: 0.59 ,  average_token: 58.9, count:100
# average_f1_score: 0.585 ,  average_token: 107.18, count:100
# average_f1_score: 0.06 ,  average_token: 8.76, count:100
# average_f1_score: 0.525 ,  average_token: 85.73, count:100
# average_f1_score: 0.575 ,  average_token: 84.21, count:100
# average_f1_score: 0.155 ,  average_token: 172.43, count:100
# average_f1_score: 0.595 ,  average_token: 70.17, count:100
# average_f1_score: 0.545 ,  average_token: 111.79, count:100
# average_f1_score: 0.575 ,  average_token: 60.03, count:100
# average_f1_score: 0.545 ,  average_token: 64.85, count:100
# average_f1_score: 0.565 ,  average_token: 84.97, count:100
# average_f1_score: 0.565 ,  average_token: 79.66, count:100
# average_f1_score: 0.595 ,  average_token: 85.01, count:100
# average_f1_score: 0.555 ,  average_token: 99.79, count:100
# average_f1_score: 0.575 ,  average_token: 93.04, count:100
# average_f1_score: 0.585 ,  average_token: 82.47, count:100
# average_f1_score: 0.575 ,  average_token: 36.71, count:100
# average_f1_score: 0.36 ,  average_token: 58.67, count:100
# average_f1_score: 0.48 ,  average_token: 91.29, count:100
# average_f1_score: 0.61 ,  average_token: 75.22, count:100
# average_f1_score: 0.599 ,  average_token: 51.28, count:100
# average_f1_score: 0.58 ,  average_token: 83.99, count:100
# average_f1_score: 0.59 ,  average_token: 87.14, count:100
# average_f1_score: 0.62 ,  average_token: 55.81, count:100
# average_f1_score: 0.525 ,  average_token: 100.95, count:100
# average_f1_score: 0.585 ,  average_token: 144.86, count:100
# average_f1_score: 0.595 ,  average_token: 66.37, count:100
# average_f1_score: 0.565 ,  average_token: 93.83, count:100
# average_f1_score: 0.565 ,  average_token: 83.33, count:100
# average_f1_score: 0.555 ,  average_token: 97.98, count:100
# average_f1_score: 0.595 ,  average_token: 112.14, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 75.84, count:100
# average_f1_score: 0.539 ,  average_token: 73.33, count:100
# average_f1_score: 0.585 ,  average_token: 76.27, count:100
# average_f1_score: 0.52 ,  average_token: 123.31, count:100
# average_f1_score: 0.555 ,  average_token: 84.93, count:100
# average_f1_score: 0.599 ,  average_token: 71.88, count:100
# average_f1_score: 0.595 ,  average_token: 86.1, count:100
# average_f1_score: 0.595 ,  average_token: 52.51, count:100
# average_f1_score: 0.555 ,  average_token: 58.7, count:100
# average_f1_score: 0.595 ,  average_token: 99.98, count:100
# average_f1_score: 0.555 ,  average_token: 81.78, count:100
# average_f1_score: 0.35 ,  average_token: 156.12, count:100
# average_f1_score: 0.5597142857142857 ,  average_token: 161.31, count:100
# average_f1_score: 0.545 ,  average_token: 121.92, count:100
# average_f1_score: 0.555 ,  average_token: 71.84, count:100
# average_f1_score: 0.615 ,  average_token: 43.87, count:100
# average_f1_score: 0.635 ,  average_token: 85.9, count:100
# average_f1_score: 0.545 ,  average_token: 53.16, count:100
# average_f1_score: 0.49 ,  average_token: 156.12, count:100
# average_f1_score: 0.515 ,  average_token: 52.61, count:100
# average_f1_score: 0.565 ,  average_token: 90.3, count:100
# average_f1_score: 0.595 ,  average_token: 55.51, count:100
# average_f1_score: 0.54 ,  average_token: 123.42, count:100
# average_f1_score: 0.63 ,  average_token: 48.7, count:100
# average_f1_score: 0.565 ,  average_token: 91.9, count:100
# average_f1_score: 0.599 ,  average_token: 114.55, count:100
# average_f1_score: 0.585 ,  average_token: 112.61, count:100
# average_f1_score: 0.595 ,  average_token: 66.89, count:100
# average_f1_score: 0.635 ,  average_token: 54.49, count:100
# average_f1_score: 0.465 ,  average_token: 123.86, count:100
# average_f1_score: 0.635 ,  average_token: 97.3, count:100
# average_f1_score: 0.544 ,  average_token: 49.61, count:100
# average_f1_score: 0.475 ,  average_token: 114.65, count:100
# average_f1_score: 0.57 ,  average_token: 106.24, count:100
# average_f1_score: 0.165 ,  average_token: 176.89, count:100
# average_f1_score: 0.645 ,  average_token: 58.37, count:100
# average_f1_score: 0.55 ,  average_token: 104.07, count:100
# average_f1_score: 0.65 ,  average_token: 42.65, count:100
# average_f1_score: 0.555 ,  average_token: 80.82, count:100
# average_f1_score: 0.565 ,  average_token: 71.93, count:100
# average_f1_score: 0.335 ,  average_token: 142.36, count:100
# average_f1_score: 0.515 ,  average_token: 94.1, count:100
# average_f1_score: 0.585 ,  average_token: 85.28, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 80.03, count:100
# average_f1_score: 0.545 ,  average_token: 61.35, count:100
# average_f1_score: 0.615 ,  average_token: 69.88, count:100
# average_f1_score: 0.545 ,  average_token: 97.87, count:100
# average_f1_score: 0.645 ,  average_token: 52.73, count:100
# average_f1_score: 0.57 ,  average_token: 70.89, count:100
# average_f1_score: 0.615 ,  average_token: 46.26, count:100
# average_f1_score: 0.649 ,  average_token: 45.32, count:100
# average_f1_score: 0.545 ,  average_token: 79.95, count:100
# average_f1_score: 0.52 ,  average_token: 161.93, count:100
# average_f1_score: 0.545 ,  average_token: 74.17, count:100
# average_f1_score: 0.585 ,  average_token: 54.29, count:100
# average_f1_score: 0.16 ,  average_token: 33.16, count:100
# average_f1_score: 0.55 ,  average_token: 65.9, count:100
# average_f1_score: 0.585 ,  average_token: 80.21, count:100
# average_f1_score: 0.56 ,  average_token: 49.02, count:100
# average_f1_score: 0.425 ,  average_token: 131.65, count:100
# average_f1_score: 0.615 ,  average_token: 51.1, count:100
# average_f1_score: 0.515 ,  average_token: 117.74, count:100
# average_f1_score: 0.54 ,  average_token: 86.37, count:100
# average_f1_score: 0.589 ,  average_token: 58.53, count:100
# average_f1_score: 0.595 ,  average_token: 78.69, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 130.44, count:100
# average_f1_score: 0.545 ,  average_token: 77.96, count:100
# average_f1_score: 0.575 ,  average_token: 60.96, count:100
# average_f1_score: 0.444 ,  average_token: 153.45, count:100
# average_f1_score: 0.625 ,  average_token: 48.51, count:100
# average_f1_score: 0.59 ,  average_token: 61.25, count:100
# average_f1_score: 0.55 ,  average_token: 120.17, count:100
# average_f1_score: 0.465 ,  average_token: 79.23, count:100
# average_f1_score: 0.58 ,  average_token: 45.94, count:100
# average_f1_score: 0.585 ,  average_token: 76.54, count:100
# average_f1_score: 0.57 ,  average_token: 130.78, count:100
# average_f1_score: 0.575 ,  average_token: 51.42, count:100
# average_f1_score: 0.599 ,  average_token: 48.69, count:100
# average_f1_score: 0.585 ,  average_token: 106.45, count:100
# average_f1_score: 0.515 ,  average_token: 85.34, count:100
# average_f1_score: 0.545 ,  average_token: 79.27, count:100
# average_f1_score: 0.614 ,  average_token: 47.66, count:100
# average_f1_score: 0.059000000000000004 ,  average_token: 218.47, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 87.84, count:100
# average_f1_score: 0.589 ,  average_token: 70.27, count:100
# average_f1_score: 0.565 ,  average_token: 65.75, count:100
# average_f1_score: 0.605 ,  average_token: 80.48, count:100
# average_f1_score: 0.465 ,  average_token: 112.61, count:100
# average_f1_score: 0.61 ,  average_token: 87.58, count:100
# average_f1_score: 0.615 ,  average_token: 75.35, count:100
# average_f1_score: 0.574 ,  average_token: 58.95, count:100
# average_f1_score: 0.665 ,  average_token: 31.87, count:100
# average_f1_score: 0.539 ,  average_token: 70.1, count:100
# average_f1_score: 0.595 ,  average_token: 49.54, count:100
# average_f1_score: 0.575 ,  average_token: 69.76, count:100
# average_f1_score: 0.57 ,  average_token: 49.99, count:100
# average_f1_score: 0.685 ,  average_token: 81.88, count:100
# average_f1_score: 0.619 ,  average_token: 40.78, count:100
# average_f1_score: 0.625 ,  average_token: 82.13, count:100
# average_f1_score: 0.595 ,  average_token: 80.86, count:100
# average_f1_score: 0.605 ,  average_token: 77.67, count:100
# average_f1_score: 0.625 ,  average_token: 70.04, count:100
# average_f1_score: 0.63 ,  average_token: 59.07, count:100
# average_f1_score: 0.589 ,  average_token: 64.46, count:100
# average_f1_score: 0.605 ,  average_token: 81.38, count:100
# average_f1_score: 0.565 ,  average_token: 56.82, count:100
# average_f1_score: 0.665 ,  average_token: 51.46, count:100
# average_f1_score: 0.605 ,  average_token: 75.76, count:100
# average_f1_score: 0.63 ,  average_token: 60.03, count:100
# average_f1_score: 0.609 ,  average_token: 44.05, count:100
# average_f1_score: 0.59 ,  average_token: 90.23, count:100
# average_f1_score: 0.615 ,  average_token: 42.06, count:100
# average_f1_score: 0.565 ,  average_token: 116.28, count:100
# average_f1_score: 0.595 ,  average_token: 57.41, count:100
# average_f1_score: 0.56 ,  average_token: 21.41, count:100
# average_f1_score: 0.475 ,  average_token: 75.39, count:100
# average_f1_score: 0.475 ,  average_token: 94.58, count:100
# average_f1_score: 0.35 ,  average_token: 150.47, count:100
# average_f1_score: 0.569 ,  average_token: 52.8, count:100
# average_f1_score: 0.625 ,  average_token: 82.23, count:100
# average_f1_score: 0.629 ,  average_token: 98.1, count:100
# average_f1_score: 0.555 ,  average_token: 103.49, count:100
# average_f1_score: 0.6 ,  average_token: 74.12, count:100
# average_f1_score: 0.529 ,  average_token: 89.29, count:100
# average_f1_score: 0.445 ,  average_token: 99.49, count:100
# average_f1_score: 0.565 ,  average_token: 129.66, count:100
# average_f1_score: 0.57 ,  average_token: 124.42, count:100
# average_f1_score: 0.625 ,  average_token: 50.99, count:100
# average_f1_score: 0.54 ,  average_token: 78.76, count:100
# average_f1_score: 0.295 ,  average_token: 149.65, count:100
# average_f1_score: 0.57 ,  average_token: 75.51, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 69.73, count:100
# average_f1_score: 0.495 ,  average_token: 133.38, count:100
# average_f1_score: 0.47 ,  average_token: 99.7, count:100
# average_f1_score: 0.575 ,  average_token: 90.75, count:100
# average_f1_score: 0.545 ,  average_token: 116.99, count:100
# average_f1_score: 0.585 ,  average_token: 68.57, count:100
# average_f1_score: 0.555 ,  average_token: 69.51, count:100
# average_f1_score: 0.615 ,  average_token: 53.81, count:100
# average_f1_score: 0.56 ,  average_token: 106.75, count:100
# average_f1_score: 0.525 ,  average_token: 103.89, count:100
# average_f1_score: 0.625 ,  average_token: 51.69, count:100
# average_f1_score: 0.3 ,  average_token: 173.79, count:100
# average_f1_score: 0.564 ,  average_token: 91.39, count:100
# average_f1_score: 0.575 ,  average_token: 84.78, count:100
# average_f1_score: 0.33899999999999997 ,  average_token: 140.17, count:100
# average_f1_score: 0.579 ,  average_token: 56.79, count:100
# average_f1_score: 0.535 ,  average_token: 91.83, count:100
# average_f1_score: 0.57 ,  average_token: 53.64, count:100
# average_f1_score: 0.585 ,  average_token: 83.0, count:100
# average_f1_score: 0.505 ,  average_token: 127.18, count:100
# average_f1_score: 0.569 ,  average_token: 63.01, count:100
# average_f1_score: 0.615 ,  average_token: 54.4, count:100
# average_f1_score: 0.585 ,  average_token: 65.83, count:100
# average_f1_score: 0.519 ,  average_token: 117.07, count:100
# average_f1_score: 0.49 ,  average_token: 127.35, count:100
# average_f1_score: 0.439 ,  average_token: 127.39, count:100
# average_f1_score: 0.62 ,  average_token: 101.21, count:100
# average_f1_score: 0.6 ,  average_token: 49.22, count:100
# average_f1_score: 0.605 ,  average_token: 100.37, count:100
# average_f1_score: 0.465 ,  average_token: 82.92, count:100
# average_f1_score: 0.605 ,  average_token: 86.74, count:100
# average_f1_score: 0.54 ,  average_token: 74.5, count:100
# average_f1_score: 0.61 ,  average_token: 84.42, count:100
# average_f1_score: 0.645 ,  average_token: 50.42, count:100
# average_f1_score: 0.64 ,  average_token: 62.52, count:100
# average_f1_score: 0.595 ,  average_token: 90.67, count:100
# average_f1_score: 0.585 ,  average_token: 48.99, count:100
# average_f1_score: 0.455 ,  average_token: 101.9, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 97.09, count:100
# average_f1_score: 0.545 ,  average_token: 75.42, count:100
# average_f1_score: 0.05 ,  average_token: 117.66, count:100
# average_f1_score: 0.525 ,  average_token: 99.47, count:100
# average_f1_score: 0.485 ,  average_token: 123.18, count:100
# average_f1_score: 0.575 ,  average_token: 86.23, count:100
# average_f1_score: 0.535 ,  average_token: 50.59, count:100
# average_f1_score: 0.565 ,  average_token: 86.85, count:100
# average_f1_score: 0.64 ,  average_token: 54.94, count:100
# average_f1_score: 0.55 ,  average_token: 110.82, count:100
# average_f1_score: 0.575 ,  average_token: 85.59, count:100
# average_f1_score: 0.539 ,  average_token: 70.27, count:100
# average_f1_score: 0.6 ,  average_token: 72.58, count:100
# average_f1_score: 0.585 ,  average_token: 102.52, count:100
# average_f1_score: 0.625 ,  average_token: 81.35, count:100
# average_f1_score: 0.45399999999999996 ,  average_token: 95.17, count:100
# average_f1_score: 0.605 ,  average_token: 58.59, count:100
# average_f1_score: 0.579 ,  average_token: 56.53, count:100
# average_f1_score: 0.615 ,  average_token: 108.69, count:100
# average_f1_score: 0.445 ,  average_token: 127.58, count:100
# average_f1_score: 0.61 ,  average_token: 52.9, count:100
# average_f1_score: 0.29 ,  average_token: 54.71, count:100
# average_f1_score: 0.565 ,  average_token: 58.32, count:100
# average_f1_score: 0.555 ,  average_token: 85.54, count:100
# average_f1_score: 0.32 ,  average_token: 123.52, count:100
# average_f1_score: 0.619 ,  average_token: 52.27, count:100
# average_f1_score: 0.565 ,  average_token: 73.29, count:100
# average_f1_score: 0.63 ,  average_token: 72.44, count:100
# average_f1_score: 0.565 ,  average_token: 108.35, count:100
# average_f1_score: 0.58 ,  average_token: 43.05, count:100
# average_f1_score: 0.4 ,  average_token: 151.37, count:100
# average_f1_score: 0.555 ,  average_token: 47.19, count:100
# average_f1_score: 0.46166666666666667 ,  average_token: 148.99, count:100
# average_f1_score: 0.589 ,  average_token: 40.14, count:100
# average_f1_score: 0.579 ,  average_token: 54.58, count:100
# average_f1_score: 0.595 ,  average_token: 114.52, count:100
# average_f1_score: 0.6 ,  average_token: 51.28, count:100
# average_f1_score: 0.565 ,  average_token: 88.2, count:100
# average_f1_score: 0.35 ,  average_token: 130.91, count:100
# average_f1_score: 0.585 ,  average_token: 92.21, count:100
# average_f1_score: 0.595 ,  average_token: 58.78, count:100
# average_f1_score: 0.325 ,  average_token: 93.48, count:100
# average_f1_score: 0.535 ,  average_token: 75.11, count:100
# average_f1_score: 0.635 ,  average_token: 51.2, count:100
# average_f1_score: 0.595 ,  average_token: 73.77, count:100
# average_f1_score: 0.555 ,  average_token: 58.74, count:100
# average_f1_score: 0.485 ,  average_token: 119.56, count:100
# average_f1_score: 0.62 ,  average_token: 61.8, count:100
# average_f1_score: 0.534 ,  average_token: 66.65, count:100
# average_f1_score: 0.615 ,  average_token: 71.69, count:100
# average_f1_score: 0.57 ,  average_token: 70.8, count:100
# average_f1_score: 0.3983333333333334 ,  average_token: 144.86, count:100
# average_f1_score: 0.595 ,  average_token: 80.67, count:100
# average_f1_score: 0.595 ,  average_token: 84.8, count:100
# average_f1_score: 0.615 ,  average_token: 80.35, count:100
# average_f1_score: 0.579 ,  average_token: 50.41, count:100
# average_f1_score: 0.545 ,  average_token: 55.13, count:100
# average_f1_score: 0.589 ,  average_token: 57.28, count:100
# average_f1_score: 0.505 ,  average_token: 130.99, count:100
# average_f1_score: 0.595 ,  average_token: 78.05, count:100
# average_f1_score: 0.3 ,  average_token: 53.55, count:100
# average_f1_score: 0.595 ,  average_token: 72.12, count:100
# average_f1_score: 0.575 ,  average_token: 59.74, count:100
# average_f1_score: 0.47 ,  average_token: 138.9, count:100
# average_f1_score: 0.565 ,  average_token: 85.81, count:100
# average_f1_score: 0.45899999999999996 ,  average_token: 102.21, count:100
# average_f1_score: 0.609 ,  average_token: 82.67, count:100
# average_f1_score: 0.4 ,  average_token: 93.72, count:100
# average_f1_score: 0.565 ,  average_token: 43.66, count:100
# average_f1_score: 0.5 ,  average_token: 120.61, count:100
# average_f1_score: 0.615 ,  average_token: 51.47, count:100
# average_f1_score: 0.455 ,  average_token: 161.12, count:100
# average_f1_score: 0.535 ,  average_token: 71.11, count:100
# average_f1_score: 0.38 ,  average_token: 139.81, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 102.32, count:100
# average_f1_score: 0.579 ,  average_token: 60.35, count:100
# average_f1_score: 0.655 ,  average_token: 37.48, count:100
# average_f1_score: 0.599 ,  average_token: 64.19, count:100
# average_f1_score: 0.579 ,  average_token: 49.05, count:100
# average_f1_score: 0.508 ,  average_token: 51.52, count:100
# average_f1_score: 0.645 ,  average_token: 46.21, count:100
# average_f1_score: 0.485 ,  average_token: 90.53, count:100
# average_f1_score: 0.615 ,  average_token: 77.17, count:100
# average_f1_score: 0.455 ,  average_token: 140.18, count:100
# average_f1_score: 0.365 ,  average_token: 75.59, count:100
# average_f1_score: 0.535 ,  average_token: 84.13, count:100
# average_f1_score: 0.595 ,  average_token: 52.96, count:100
# average_f1_score: 0.565 ,  average_token: 77.82, count:100
# average_f1_score: 0.615 ,  average_token: 116.16, count:100
# average_f1_score: 0.59 ,  average_token: 46.2, count:100
# average_f1_score: 0.545 ,  average_token: 117.5, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 69.34, count:100
# average_f1_score: 0.575 ,  average_token: 91.18, count:100
# average_f1_score: 0.524 ,  average_token: 92.95, count:100
# average_f1_score: 0.485 ,  average_token: 149.35, count:100
# average_f1_score: 0.595 ,  average_token: 83.15, count:100
# average_f1_score: 0.66 ,  average_token: 64.47, count:100
# average_f1_score: 0.595 ,  average_token: 80.27, count:100
# average_f1_score: 0.26 ,  average_token: 119.98, count:100
# average_f1_score: 0.539 ,  average_token: 67.04, count:100
# average_f1_score: 0.56 ,  average_token: 77.56, count:100
# average_f1_score: 0.62 ,  average_token: 53.81, count:100
# average_f1_score: 0.609 ,  average_token: 57.43, count:100
# average_f1_score: 0.585 ,  average_token: 112.44, count:100
# average_f1_score: 0.545 ,  average_token: 72.27, count:100
# average_f1_score: 0.645 ,  average_token: 84.55, count:100
# average_f1_score: 0.589 ,  average_token: 50.77, count:100
# average_f1_score: 0.49 ,  average_token: 170.25, count:100
# average_f1_score: 0.52 ,  average_token: 73.95, count:100
# average_f1_score: 0.539 ,  average_token: 106.8, count:100
# average_f1_score: 0.569 ,  average_token: 55.19, count:100
# average_f1_score: 0.535 ,  average_token: 94.03, count:100
# average_f1_score: 0.615 ,  average_token: 117.71, count:100
# average_f1_score: 0.57 ,  average_token: 119.54, count:100
# average_f1_score: 0.57 ,  average_token: 68.72, count:100
# average_f1_score: 0.535 ,  average_token: 140.16, count:100
# average_f1_score: 0.615 ,  average_token: 126.7, count:100
# average_f1_score: 0.635 ,  average_token: 41.45, count:100
# average_f1_score: 0.589 ,  average_token: 71.48, count:100
# average_f1_score: 0.55 ,  average_token: 41.63, count:100
# average_f1_score: 0.565 ,  average_token: 52.56, count:100
# average_f1_score: 0.515 ,  average_token: 101.71, count:100
# average_f1_score: 0.605 ,  average_token: 78.11, count:100
# average_f1_score: 0.615 ,  average_token: 84.8, count:100
# average_f1_score: 0.575 ,  average_token: 78.06, count:100
# average_f1_score: 0.434 ,  average_token: 143.41, count:100
# average_f1_score: 0.6 ,  average_token: 46.17, count:100
# average_f1_score: 0.605 ,  average_token: 78.87, count:100
# average_f1_score: 0.575 ,  average_token: 80.0, count:100
# average_f1_score: 0.645 ,  average_token: 52.16, count:100
# average_f1_score: 0.56 ,  average_token: 102.77, count:100
# average_f1_score: 0.665 ,  average_token: 88.32, count:100
# average_f1_score: 0.629 ,  average_token: 59.21, count:100
# average_f1_score: 0.325 ,  average_token: 28.45, count:100
# average_f1_score: 0.525 ,  average_token: 93.12, count:100
# average_f1_score: 0.589 ,  average_token: 57.94, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 77.47, count:100
# average_f1_score: 0.405 ,  average_token: 142.97, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 57.61, count:100
# average_f1_score: 0.415 ,  average_token: 163.85, count:100
# average_f1_score: 0.624 ,  average_token: 100.06, count:100
# average_f1_score: 0.565 ,  average_token: 68.74, count:100
# average_f1_score: 0.585 ,  average_token: 76.51, count:100
# average_f1_score: 0.525 ,  average_token: 82.35, count:100
# average_f1_score: 0.595 ,  average_token: 88.15, count:100
# average_f1_score: 0.62 ,  average_token: 53.65, count:100
# average_f1_score: 0.539 ,  average_token: 68.56, count:100
# average_f1_score: 0.61 ,  average_token: 61.44, count:100
# average_f1_score: 0.57 ,  average_token: 80.21, count:100
# average_f1_score: 0.615 ,  average_token: 54.97, count:100
# average_f1_score: 0.265 ,  average_token: 34.52, count:100
# average_f1_score: 0.299 ,  average_token: 112.31, count:100
# average_f1_score: 0.629 ,  average_token: 44.12, count:100
# average_f1_score: 0.265 ,  average_token: 145.66, count:100
# average_f1_score: 0.625 ,  average_token: 54.36, count:100
# average_f1_score: 0.565 ,  average_token: 85.45, count:100
# average_f1_score: 0.539 ,  average_token: 103.88, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 42.28, count:100
# average_f1_score: 0.239 ,  average_token: 180.36, count:100
# average_f1_score: 0.449 ,  average_token: 139.06, count:100
# average_f1_score: 0.609 ,  average_token: 46.26, count:100
# average_f1_score: 0.595 ,  average_token: 121.42, count:100
# average_f1_score: 0.625 ,  average_token: 92.94, count:100
# average_f1_score: 0.585 ,  average_token: 70.88, count:100
# average_f1_score: 0.565 ,  average_token: 82.11, count:100
# average_f1_score: 0.585 ,  average_token: 65.1, count:100
# average_f1_score: 0.605 ,  average_token: 63.27, count:100
# average_f1_score: 0.575 ,  average_token: 87.98, count:100
# average_f1_score: 0.615 ,  average_token: 82.16, count:100
# average_f1_score: 0.545 ,  average_token: 104.02, count:100
# average_f1_score: 0.635 ,  average_token: 47.78, count:100
# average_f1_score: 0.575 ,  average_token: 89.41, count:100
# average_f1_score: 0.625 ,  average_token: 49.41, count:100
# average_f1_score: 0.555 ,  average_token: 77.05, count:100
# average_f1_score: 0.585 ,  average_token: 81.37, count:100
# average_f1_score: 0.47 ,  average_token: 122.81, count:100
# average_f1_score: 0.595 ,  average_token: 60.55, count:100
# average_f1_score: 0.585 ,  average_token: 100.06, count:100
# average_f1_score: 0.515 ,  average_token: 127.31, count:100
# average_f1_score: 0.485 ,  average_token: 112.12, count:100
# average_f1_score: 0.595 ,  average_token: 67.33, count:100
# average_f1_score: 0.405 ,  average_token: 136.03, count:100
# average_f1_score: 0.535 ,  average_token: 72.91, count:100
# average_f1_score: 0.54 ,  average_token: 73.82, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 53.56, count:100
# average_f1_score: 0.595 ,  average_token: 85.74, count:100
# average_f1_score: 0.505 ,  average_token: 97.65, count:100
# average_f1_score: 0.56 ,  average_token: 78.07, count:100
# average_f1_score: 0.605 ,  average_token: 69.71, count:100
# average_f1_score: 0.545 ,  average_token: 52.58, count:100
# average_f1_score: 0.565 ,  average_token: 87.44, count:100
# average_f1_score: 0.605 ,  average_token: 68.35, count:100
# average_f1_score: 0.579 ,  average_token: 82.44, count:100
# average_f1_score: 0.485 ,  average_token: 120.38, count:100
# average_f1_score: 0.51 ,  average_token: 77.87, count:100
# average_f1_score: 0.55 ,  average_token: 84.79, count:100
# average_f1_score: 0.525 ,  average_token: 126.47, count:100
# average_f1_score: 0.63 ,  average_token: 65.37, count:100
# average_f1_score: 0.575 ,  average_token: 75.6, count:100
# average_f1_score: 0.489 ,  average_token: 140.18, count:100
# average_f1_score: 0.38 ,  average_token: 94.81, count:100
# average_f1_score: 0.585 ,  average_token: 79.83, count:100
# average_f1_score: 0.569 ,  average_token: 52.65, count:100
# average_f1_score: 0.46 ,  average_token: 48.29, count:100
# average_f1_score: 0.619 ,  average_token: 44.96, count:100
# average_f1_score: 0.54 ,  average_token: 117.06, count:100
# average_f1_score: 0.629 ,  average_token: 47.55, count:100
# average_f1_score: 0.545 ,  average_token: 74.46, count:100
# average_f1_score: 0.59 ,  average_token: 68.18, count:100
# average_f1_score: 0.625 ,  average_token: 86.35, count:100
# average_f1_score: 0.555 ,  average_token: 46.99, count:100
# average_f1_score: 0.585 ,  average_token: 78.4, count:100
# average_f1_score: 0.545 ,  average_token: 107.37, count:100
# average_f1_score: 0.595 ,  average_token: 93.56, count:100
# average_f1_score: 0.575 ,  average_token: 132.12, count:100
# average_f1_score: 0.529 ,  average_token: 80.85, count:100
# average_f1_score: 0.59 ,  average_token: 142.68, count:100
# average_f1_score: 0.545 ,  average_token: 80.1, count:100
# average_f1_score: 0.475 ,  average_token: 154.99, count:100
# average_f1_score: 0.595 ,  average_token: 80.68, count:100
# average_f1_score: 0.545 ,  average_token: 85.75, count:100
# average_f1_score: 0.615 ,  average_token: 81.07, count:100
# average_f1_score: 0.555 ,  average_token: 80.22, count:100
# average_f1_score: 0.58 ,  average_token: 61.42, count:100
# average_f1_score: 0.555 ,  average_token: 96.13, count:100
# average_f1_score: 0.62 ,  average_token: 65.55, count:100
# average_f1_score: 0.595 ,  average_token: 82.24, count:100
# average_f1_score: 0.585 ,  average_token: 60.76, count:100
# average_f1_score: 0.575 ,  average_token: 71.28, count:100
# average_f1_score: 0.565 ,  average_token: 110.0, count:100
# average_f1_score: 0.539 ,  average_token: 53.16, count:100
# average_f1_score: 0.48 ,  average_token: 157.61, count:100
# average_f1_score: 0.51 ,  average_token: 93.13, count:100
# average_f1_score: 0.55 ,  average_token: 87.47, count:100
# average_f1_score: 0.62 ,  average_token: 94.57, count:100
# average_f1_score: 0.585 ,  average_token: 81.57, count:100
# average_f1_score: 0.6 ,  average_token: 98.97, count:100
# average_f1_score: 0.455 ,  average_token: 119.5, count:100
# average_f1_score: 0.555 ,  average_token: 55.41, count:100
# average_f1_score: 0.555 ,  average_token: 113.45, count:100
# average_f1_score: 0.555 ,  average_token: 52.09, count:100
# average_f1_score: 0.555 ,  average_token: 74.97, count:100
# average_f1_score: 0.555 ,  average_token: 85.27, count:100
# average_f1_score: 0.585 ,  average_token: 80.21, count:100
# average_f1_score: 0.545 ,  average_token: 144.62, count:100
# average_f1_score: 0.565 ,  average_token: 54.64, count:100
# average_f1_score: 0.575 ,  average_token: 53.3, count:100
# average_f1_score: 0.565 ,  average_token: 86.1, count:100
# average_f1_score: 0.565 ,  average_token: 62.82, count:100
# average_f1_score: 0.585 ,  average_token: 43.25, count:100
# average_f1_score: 0.565 ,  average_token: 81.99, count:100
# average_f1_score: 0.31 ,  average_token: 56.04, count:100
# average_f1_score: 0.5956666666666667 ,  average_token: 56.07, count:100
# average_f1_score: 0.425 ,  average_token: 66.19, count:100
# average_f1_score: 0.565 ,  average_token: 76.03, count:100
# average_f1_score: 0.55 ,  average_token: 107.62, count:100
# average_f1_score: 0.545 ,  average_token: 105.04, count:100
# average_f1_score: 0.534 ,  average_token: 102.13, count:100
# average_f1_score: 0.605 ,  average_token: 84.49, count:100
# average_f1_score: 0.515 ,  average_token: 55.88, count:100
# average_f1_score: 0.565 ,  average_token: 47.0, count:100
# average_f1_score: 0.479 ,  average_token: 72.0, count:100
# average_f1_score: 0.645 ,  average_token: 87.21, count:100
# average_f1_score: 0.54 ,  average_token: 111.77, count:100
# average_f1_score: 0.61 ,  average_token: 62.86, count:100
# average_f1_score: 0.4516666666666667 ,  average_token: 70.64, count:100
# average_f1_score: 0.605 ,  average_token: 78.57, count:100
# average_f1_score: 0.615 ,  average_token: 120.34, count:100
# average_f1_score: 0.565 ,  average_token: 88.18, count:100
# average_f1_score: 0.555 ,  average_token: 71.75, count:100
# average_f1_score: 0.569 ,  average_token: 81.73, count:100
# average_f1_score: 0.585 ,  average_token: 88.19, count:100
# average_f1_score: 0.575 ,  average_token: 76.58, count:100
# average_f1_score: 0.585 ,  average_token: 50.88, count:100
# average_f1_score: 0.61 ,  average_token: 88.45, count:100
# average_f1_score: 0.6 ,  average_token: 74.59, count:100
# average_f1_score: 0.585 ,  average_token: 77.87, count:100
# average_f1_score: 0.595 ,  average_token: 51.11, count:100
# average_f1_score: 0.595 ,  average_token: 70.24, count:100
# average_f1_score: 0.585 ,  average_token: 76.23, count:100
# average_f1_score: 0.535 ,  average_token: 54.66, count:100
# average_f1_score: 0.525 ,  average_token: 100.0, count:100
# average_f1_score: 0.225 ,  average_token: 175.4, count:100
# average_f1_score: 0.415 ,  average_token: 167.94, count:100
# average_f1_score: 0.53 ,  average_token: 22.67, count:100
# average_f1_score: 0.585 ,  average_token: 83.07, count:100
# average_f1_score: 0.605 ,  average_token: 85.46, count:100
# average_f1_score: 0.415 ,  average_token: 138.82, count:100
# average_f1_score: 0.625 ,  average_token: 50.42, count:100
# average_f1_score: 0.585 ,  average_token: 81.45, count:100
# average_f1_score: 0.36 ,  average_token: 137.08, count:100
# average_f1_score: 0.09 ,  average_token: 63.57, count:100
# average_f1_score: 0.555 ,  average_token: 78.35, count:100
# average_f1_score: 0.555 ,  average_token: 87.34, count:100
# average_f1_score: 0.515 ,  average_token: 141.26, count:100
# average_f1_score: 0.43 ,  average_token: 129.1, count:100
# average_f1_score: 0.485 ,  average_token: 106.18, count:100
# average_f1_score: 0.15 ,  average_token: 176.3, count:100
# average_f1_score: 0.595 ,  average_token: 63.47, count:100
# average_f1_score: 0.585 ,  average_token: 74.62, count:100
# average_f1_score: 0.615 ,  average_token: 49.75, count:100
# average_f1_score: 0.575 ,  average_token: 51.36, count:100
# average_f1_score: 0.565 ,  average_token: 100.51, count:100
# average_f1_score: 0.63 ,  average_token: 77.9, count:100
# average_f1_score: 0.579 ,  average_token: 46.47, count:100
# average_f1_score: 0.01 ,  average_token: 35.48, count:100
# average_f1_score: 0.58 ,  average_token: 84.55, count:100
# average_f1_score: 0.529 ,  average_token: 77.95, count:100
# average_f1_score: 0.369 ,  average_token: 36.6, count:100
# average_f1_score: 0.565 ,  average_token: 82.98, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 84.76, count:100
# average_f1_score: 0.605 ,  average_token: 88.08, count:100
# average_f1_score: 0.535 ,  average_token: 125.26, count:100
# average_f1_score: 0.595 ,  average_token: 136.13, count:100
# average_f1_score: 0.295 ,  average_token: 75.08, count:100
# average_f1_score: 0.475 ,  average_token: 118.95, count:100
# average_f1_score: 0.13 ,  average_token: 27.34, count:100
# average_f1_score: 0.46 ,  average_token: 153.37, count:100
# average_f1_score: 0.595 ,  average_token: 53.77, count:100
# average_f1_score: 0.555 ,  average_token: 83.76, count:100
# average_f1_score: 0.584 ,  average_token: 75.59, count:100
# average_f1_score: 0.579 ,  average_token: 90.56, count:100
# average_f1_score: 0.6 ,  average_token: 83.06, count:100
# average_f1_score: 0.555 ,  average_token: 38.42, count:100
# average_f1_score: 0.2 ,  average_token: 141.91, count:100
# average_f1_score: 0.545 ,  average_token: 54.34, count:100
# average_f1_score: 0.585 ,  average_token: 92.33, count:100
# average_f1_score: 0.58 ,  average_token: 66.93, count:100
# average_f1_score: 0.22 ,  average_token: 196.62, count:100
# average_f1_score: 0.585 ,  average_token: 78.81, count:100
# average_f1_score: 0.6 ,  average_token: 112.36, count:100
# average_f1_score: 0.615 ,  average_token: 69.97, count:100
# average_f1_score: 0.565 ,  average_token: 97.1, count:100
# average_f1_score: 0.345 ,  average_token: 161.27, count:100
# average_f1_score: 0.515 ,  average_token: 89.8, count:100
# average_f1_score: 0.589 ,  average_token: 55.44, count:100
# average_f1_score: 0.63 ,  average_token: 80.54, count:100
# average_f1_score: 0.609 ,  average_token: 46.02, count:100
# average_f1_score: 0.605 ,  average_token: 64.09, count:100
# average_f1_score: 0.565 ,  average_token: 78.6, count:100
# average_f1_score: 0.665 ,  average_token: 39.09, count:100
# average_f1_score: 0.445 ,  average_token: 89.22, count:100
# average_f1_score: 0.51 ,  average_token: 144.38, count:100
# average_f1_score: 0.655 ,  average_token: 68.84, count:100
# average_f1_score: 0.605 ,  average_token: 57.76, count:100
# average_f1_score: 0.565 ,  average_token: 69.18, count:100
# average_f1_score: 0.57 ,  average_token: 81.92, count:100
# average_f1_score: 0.615 ,  average_token: 106.25, count:100
# average_f1_score: 0.6 ,  average_token: 89.6, count:100
# average_f1_score: 0.48 ,  average_token: 119.21, count:100
# average_f1_score: 0.565 ,  average_token: 71.8, count:100
# average_f1_score: 0.495 ,  average_token: 104.94, count:100
# average_f1_score: 0.535 ,  average_token: 104.44, count:100
# average_f1_score: 0.655 ,  average_token: 52.72, count:100
# average_f1_score: 0.615 ,  average_token: 50.85, count:100
# average_f1_score: 0.525 ,  average_token: 156.07, count:100
# average_f1_score: 0.545 ,  average_token: 85.13, count:100
# average_f1_score: 0.525 ,  average_token: 98.72, count:100
# average_f1_score: 0.615 ,  average_token: 55.3, count:100
# average_f1_score: 0.535 ,  average_token: 89.17, count:100
# average_f1_score: 0.585 ,  average_token: 82.54, count:100
# average_f1_score: 0.495 ,  average_token: 125.2, count:100
# average_f1_score: 0.585 ,  average_token: 86.27, count:100
# average_f1_score: 0.589 ,  average_token: 66.22, count:100
# average_f1_score: 0.67 ,  average_token: 63.55, count:100
# average_f1_score: 0.575 ,  average_token: 84.93, count:100
# average_f1_score: 0.55 ,  average_token: 130.85, count:100
# average_f1_score: 0.435 ,  average_token: 124.07, count:100
# average_f1_score: 0.645 ,  average_token: 70.38, count:100
# average_f1_score: 0.515 ,  average_token: 124.53, count:100
# average_f1_score: 0.565 ,  average_token: 71.78, count:100
# average_f1_score: 0.605 ,  average_token: 83.89, count:100
# average_f1_score: 0.435 ,  average_token: 131.76, count:100
# average_f1_score: 0.424 ,  average_token: 120.11, count:100
# average_f1_score: 0.625 ,  average_token: 61.91, count:100
# average_f1_score: 0.575 ,  average_token: 92.36, count:100
# average_f1_score: 0.62 ,  average_token: 76.06, count:100
# average_f1_score: 0.58 ,  average_token: 79.18, count:100
# average_f1_score: 0.515 ,  average_token: 148.88, count:100
# average_f1_score: 0.565 ,  average_token: 52.08, count:100
# average_f1_score: 0.43 ,  average_token: 157.28, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 60.49, count:100
# average_f1_score: 0.609 ,  average_token: 79.84, count:100
# average_f1_score: 0.575 ,  average_token: 107.65, count:100
# average_f1_score: 0.53 ,  average_token: 48.5, count:100
# average_f1_score: 0.595 ,  average_token: 67.05, count:100
# average_f1_score: 0.535 ,  average_token: 61.54, count:100
# average_f1_score: 0.649 ,  average_token: 110.8, count:100
# average_f1_score: 0.645 ,  average_token: 66.62, count:100
# average_f1_score: 0.455 ,  average_token: 157.15, count:100
# average_f1_score: 0.579 ,  average_token: 63.77, count:100
# average_f1_score: 0.575 ,  average_token: 88.43, count:100
# average_f1_score: 0.609 ,  average_token: 57.23, count:100
# average_f1_score: 0.13 ,  average_token: 44.79, count:100
# average_f1_score: 0.51 ,  average_token: 100.1, count:100
# average_f1_score: 0.594 ,  average_token: 50.78, count:100
# average_f1_score: 0.595 ,  average_token: 76.83, count:100
# average_f1_score: 0.595 ,  average_token: 59.02, count:100
# average_f1_score: 0.525 ,  average_token: 82.85, count:100
# average_f1_score: 0.619 ,  average_token: 60.16, count:100
# average_f1_score: 0.584 ,  average_token: 55.86, count:100
# average_f1_score: 0.564 ,  average_token: 51.15, count:100
# average_f1_score: 0.61 ,  average_token: 88.17, count:100
# average_f1_score: 0.569 ,  average_token: 66.64, count:100
# average_f1_score: 0.585 ,  average_token: 85.98, count:100
# average_f1_score: 0.485 ,  average_token: 109.83, count:100
# average_f1_score: 0.565 ,  average_token: 44.01, count:100
# average_f1_score: 0.625 ,  average_token: 50.25, count:100
# average_f1_score: 0.565 ,  average_token: 125.02, count:100
# average_f1_score: 0.589 ,  average_token: 95.53, count:100
# average_f1_score: 0.6 ,  average_token: 43.36, count:100
# average_f1_score: 0.45 ,  average_token: 154.99, count:100
# average_f1_score: 0.62 ,  average_token: 89.42, count:100
# average_f1_score: 0.375 ,  average_token: 107.61, count:100
# average_f1_score: 0.275 ,  average_token: 163.09, count:100
# average_f1_score: 0.58 ,  average_token: 52.1, count:100
# average_f1_score: 0.565 ,  average_token: 91.66, count:100
# average_f1_score: 0.1 ,  average_token: 41.5, count:100
# average_f1_score: 0.625 ,  average_token: 68.98, count:100
# average_f1_score: 0.595 ,  average_token: 79.89, count:100
# average_f1_score: 0.22 ,  average_token: 188.92, count:100
# average_f1_score: 0.609 ,  average_token: 65.19, count:100
# average_f1_score: 0.47 ,  average_token: 92.24, count:100
# average_f1_score: 0.515 ,  average_token: 108.72, count:100
# average_f1_score: 0.585 ,  average_token: 82.32, count:100
# average_f1_score: 0.555 ,  average_token: 77.1, count:100
# average_f1_score: 0.565 ,  average_token: 81.29, count:100
# average_f1_score: 0.579 ,  average_token: 79.16, count:100
# average_f1_score: 0.61 ,  average_token: 64.95, count:100
# average_f1_score: 0.585 ,  average_token: 88.01, count:100
# average_f1_score: 0.51 ,  average_token: 132.11, count:100
# average_f1_score: 0.605 ,  average_token: 47.09, count:100
# average_f1_score: 0.485 ,  average_token: 146.86, count:100
# average_f1_score: 0.575 ,  average_token: 73.06, count:100
# average_f1_score: 0.535 ,  average_token: 104.92, count:100
# average_f1_score: 0.555 ,  average_token: 119.91, count:100
# average_f1_score: 0.495 ,  average_token: 118.06, count:100
# average_f1_score: 0.58 ,  average_token: 103.35, count:100
# average_f1_score: 0.595 ,  average_token: 83.34, count:100
# average_f1_score: 0.575 ,  average_token: 81.99, count:100
# average_f1_score: 0.5 ,  average_token: 121.09, count:100
# average_f1_score: 0.615 ,  average_token: 89.61, count:100
# average_f1_score: 0.6 ,  average_token: 68.89, count:100
# average_f1_score: 0.54 ,  average_token: 46.49, count:100
# average_f1_score: 0.545 ,  average_token: 119.03, count:100
# average_f1_score: 0.425 ,  average_token: 156.01, count:100
# average_f1_score: 0.605 ,  average_token: 84.98, count:100
# average_f1_score: 0.325 ,  average_token: 72.45, count:100
# average_f1_score: 0.55 ,  average_token: 44.92, count:100
# average_f1_score: 0.415 ,  average_token: 58.29, count:100
# average_f1_score: 0.595 ,  average_token: 118.66, count:100
# average_f1_score: 0.505 ,  average_token: 134.04, count:100
# average_f1_score: 0.609 ,  average_token: 67.3, count:100
# average_f1_score: 0.575 ,  average_token: 91.83, count:100
# average_f1_score: 0.62 ,  average_token: 41.51, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 91.92, count:100
# average_f1_score: 0.595 ,  average_token: 53.97, count:100
# average_f1_score: 0.575 ,  average_token: 104.71, count:100
# average_f1_score: 0.305 ,  average_token: 120.96, count:100
# average_f1_score: 0.575 ,  average_token: 64.84, count:100
# average_f1_score: 0.605 ,  average_token: 54.02, count:100
# average_f1_score: 0.35 ,  average_token: 194.56, count:100
# average_f1_score: 0.505 ,  average_token: 122.08, count:100
# average_f1_score: 0.635 ,  average_token: 58.02, count:100
# average_f1_score: 0.515 ,  average_token: 70.44, count:100
# average_f1_score: 0.56 ,  average_token: 60.72, count:100
# average_f1_score: 0.539 ,  average_token: 91.8, count:100
# average_f1_score: 0.259 ,  average_token: 86.59, count:100
# average_f1_score: 0.565 ,  average_token: 41.32, count:100
# average_f1_score: 0.615 ,  average_token: 45.43, count:100
# average_f1_score: 0.54 ,  average_token: 138.75, count:100
# average_f1_score: 0.545 ,  average_token: 69.18, count:100
# average_f1_score: 0.595 ,  average_token: 53.24, count:100
# average_f1_score: 0.4307142857142857 ,  average_token: 136.46, count:100
# average_f1_score: 0.21 ,  average_token: 193.89, count:100
# average_f1_score: 0.645 ,  average_token: 63.23, count:100
# average_f1_score: 0.545 ,  average_token: 93.34, count:100
# average_f1_score: 0.525 ,  average_token: 86.41, count:100
# average_f1_score: 0.619 ,  average_token: 77.62, count:100
# average_f1_score: 0.555 ,  average_token: 48.16, count:100
# average_f1_score: 0.545 ,  average_token: 118.81, count:100
# average_f1_score: 0.6 ,  average_token: 57.17, count:100
# average_f1_score: 0.63 ,  average_token: 75.41, count:100
# average_f1_score: 0.57 ,  average_token: 56.92, count:100
# average_f1_score: 0.63 ,  average_token: 67.81, count:100
# average_f1_score: 0.499 ,  average_token: 126.44, count:100
# average_f1_score: 0.579 ,  average_token: 80.23, count:100
# average_f1_score: 0.599 ,  average_token: 68.11, count:100
# average_f1_score: 0.455 ,  average_token: 143.81, count:100
# average_f1_score: 0.585 ,  average_token: 63.66, count:100
# average_f1_score: 0.595 ,  average_token: 62.82, count:100
# average_f1_score: 0.565 ,  average_token: 56.3, count:100
# average_f1_score: 0.479 ,  average_token: 95.06, count:100
# average_f1_score: 0.645 ,  average_token: 61.91, count:100
# average_f1_score: 0.535 ,  average_token: 92.1, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 84.13, count:100
# average_f1_score: 0.54 ,  average_token: 66.91, count:100
# average_f1_score: 0.595 ,  average_token: 49.72, count:100
# average_f1_score: 0.475 ,  average_token: 142.59, count:100
# average_f1_score: 0.40399999999999997 ,  average_token: 125.05, count:100
# average_f1_score: 0.565 ,  average_token: 58.89, count:100
# average_f1_score: 0.619 ,  average_token: 45.69, count:100
# average_f1_score: 0.6 ,  average_token: 54.59, count:100
# average_f1_score: 0.595 ,  average_token: 49.77, count:100
# average_f1_score: 0.61 ,  average_token: 37.71, count:100
# average_f1_score: 0.595 ,  average_token: 48.18, count:100
# average_f1_score: 0.61 ,  average_token: 67.43, count:100
# average_f1_score: 0.599 ,  average_token: 40.46, count:100
# average_f1_score: 0.605 ,  average_token: 50.82, count:100
# average_f1_score: 0.37 ,  average_token: 157.86, count:100
# average_f1_score: 0.579 ,  average_token: 67.07, count:100
# average_f1_score: 0.565 ,  average_token: 92.27, count:100
# average_f1_score: 0.649 ,  average_token: 48.41, count:100
# average_f1_score: 0.639 ,  average_token: 47.51, count:100
# average_f1_score: 0.62 ,  average_token: 53.33, count:100
# average_f1_score: 0.54 ,  average_token: 74.89, count:100
# average_f1_score: 0.565 ,  average_token: 95.1, count:100
# average_f1_score: 0.605 ,  average_token: 50.5, count:100
# average_f1_score: 0.619 ,  average_token: 57.89, count:100
# average_f1_score: 0.555 ,  average_token: 90.38, count:100
# average_f1_score: 0.565 ,  average_token: 55.47, count:100
# average_f1_score: 0.565 ,  average_token: 50.04, count:100
# average_f1_score: 0.579 ,  average_token: 63.69, count:100
# average_f1_score: 0.32 ,  average_token: 90.28, count:100
# average_f1_score: 0.585 ,  average_token: 59.43, count:100
# average_f1_score: 0.565 ,  average_token: 75.62, count:100
# average_f1_score: 0.555 ,  average_token: 80.61, count:100
# average_f1_score: 0.635 ,  average_token: 65.12, count:100
# average_f1_score: 0.625 ,  average_token: 58.83, count:100
# average_f1_score: 0.545 ,  average_token: 92.51, count:100
# average_f1_score: 0.565 ,  average_token: 104.11, count:100
# average_f1_score: 0.595 ,  average_token: 47.61, count:100
# average_f1_score: 0.6 ,  average_token: 49.04, count:100
# average_f1_score: 0.475 ,  average_token: 129.83, count:100
# average_f1_score: 0.585 ,  average_token: 88.15, count:100
# average_f1_score: 0.575 ,  average_token: 88.05, count:100
# average_f1_score: 0.635 ,  average_token: 39.1, count:100
# average_f1_score: 0.555 ,  average_token: 115.47, count:100
# average_f1_score: 0.62 ,  average_token: 81.53, count:100
# average_f1_score: 0.565 ,  average_token: 81.63, count:100
# average_f1_score: 0.639 ,  average_token: 45.14, count:100
# average_f1_score: 0.565 ,  average_token: 91.75, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 84.13, count:100
# average_f1_score: 0.564 ,  average_token: 83.29, count:100
# average_f1_score: 0.15 ,  average_token: 167.79, count:100
# average_f1_score: 0.555 ,  average_token: 71.28, count:100
# average_f1_score: 0.585 ,  average_token: 84.2, count:100
# average_f1_score: 0.31 ,  average_token: 157.23, count:100
# average_f1_score: 0.645 ,  average_token: 50.6, count:100
# average_f1_score: 0.565 ,  average_token: 119.73, count:100
# average_f1_score: 0.515 ,  average_token: 153.65, count:100
# average_f1_score: 0.605 ,  average_token: 75.39, count:100
# average_f1_score: 0.589 ,  average_token: 75.73, count:100
# average_f1_score: 0.605 ,  average_token: 84.11, count:100
# average_f1_score: 0.62 ,  average_token: 61.77, count:100
# average_f1_score: 0.565 ,  average_token: 85.19, count:100
# average_f1_score: 0.555 ,  average_token: 72.49, count:100
# average_f1_score: 0.575 ,  average_token: 77.88, count:100
# average_f1_score: 0.609 ,  average_token: 50.51, count:100
# average_f1_score: 0.57 ,  average_token: 58.43, count:100
# ...
# average_f1_score: 0.62 ,  average_token: 50.31, count:100
# average_f1_score: 0.615 ,  average_token: 58.14, count:100
# average_f1_score: 0.625 ,  average_token: 139.38, count:100
# average_f1_score: 0.575 ,  average_token: 79.75, count:100
# average_f1_score: 0.33 ,  average_token: 132.09, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 67.83, count:100
# average_f1_score: 0.645 ,  average_token: 50.27, count:100
# average_f1_score: 0.525 ,  average_token: 113.87, count:100
# average_f1_score: 0.53 ,  average_token: 134.94, count:100
# average_f1_score: 0.38 ,  average_token: 134.4, count:100
# average_f1_score: 0.599 ,  average_token: 72.89, count:100
# average_f1_score: 0.54 ,  average_token: 123.8, count:100
# average_f1_score: 0.515 ,  average_token: 107.7, count:100
# average_f1_score: 0.57 ,  average_token: 51.73, count:100
# average_f1_score: 0.575 ,  average_token: 70.22, count:100
# average_f1_score: 0.56 ,  average_token: 91.95, count:100
# average_f1_score: 0.619 ,  average_token: 75.25, count:100
# average_f1_score: 0.555 ,  average_token: 68.58, count:100
# average_f1_score: 0.6 ,  average_token: 84.74, count:100
# average_f1_score: 0.545 ,  average_token: 93.09, count:100
# average_f1_score: 0.555 ,  average_token: 45.63, count:100
# average_f1_score: 0.6 ,  average_token: 70.68, count:100
# average_f1_score: 0.63 ,  average_token: 74.66, count:100
# average_f1_score: 0.605 ,  average_token: 100.94, count:100
# average_f1_score: 0.555 ,  average_token: 116.37, count:100
# average_f1_score: 0.5539999999999999 ,  average_token: 86.1, count:100
# average_f1_score: 0.6 ,  average_token: 117.91, count:100
# average_f1_score: 0.545 ,  average_token: 70.13, count:100
# average_f1_score: 0.595 ,  average_token: 73.94, count:100
# average_f1_score: 0.639 ,  average_token: 52.96, count:100
# average_f1_score: 0.36 ,  average_token: 202.18, count:100
# average_f1_score: 0.62 ,  average_token: 68.57, count:100
# average_f1_score: 0.665 ,  average_token: 53.38, count:100
# average_f1_score: 0.569 ,  average_token: 56.81, count:100
# average_f1_score: 0.605 ,  average_token: 59.74, count:100
# average_f1_score: 0.595 ,  average_token: 79.41, count:100
# average_f1_score: 0.489 ,  average_token: 122.1, count:100
# average_f1_score: 0.525 ,  average_token: 88.21, count:100
# average_f1_score: 0.16 ,  average_token: 84.71, count:100
# average_f1_score: 0.619 ,  average_token: 80.76, count:100
# average_f1_score: 0.55 ,  average_token: 91.54, count:100
# average_f1_score: 0.565 ,  average_token: 97.03, count:100
# average_f1_score: 0.599 ,  average_token: 64.69, count:100
# average_f1_score: 0.535 ,  average_token: 41.54, count:100
# average_f1_score: 0.605 ,  average_token: 50.93, count:100
# average_f1_score: 0.545 ,  average_token: 77.02, count:100
# average_f1_score: 0.615 ,  average_token: 55.16, count:100
# average_f1_score: 0.645 ,  average_token: 82.12, count:100
# average_f1_score: 0.595 ,  average_token: 66.2, count:100
# average_f1_score: 0.555 ,  average_token: 72.63, count:100
# average_f1_score: 0.605 ,  average_token: 109.83, count:100
# average_f1_score: 0.499 ,  average_token: 143.03, count:100
# average_f1_score: 0.579 ,  average_token: 53.57, count:100
# average_f1_score: 0.565 ,  average_token: 137.22, count:100
# average_f1_score: 0.615 ,  average_token: 59.1, count:100
# average_f1_score: 0.605 ,  average_token: 72.69, count:100
# average_f1_score: 0.575 ,  average_token: 90.87, count:100
# average_f1_score: 0.555 ,  average_token: 99.27, count:100
# average_f1_score: 0.57 ,  average_token: 54.78, count:100
# average_f1_score: 0.655 ,  average_token: 49.24, count:100
# average_f1_score: 0.325 ,  average_token: 115.59, count:100
# average_f1_score: 0.35 ,  average_token: 157.48, count:100
# average_f1_score: 0.565 ,  average_token: 86.61, count:100
# average_f1_score: 0.475 ,  average_token: 118.37, count:100
# average_f1_score: 0.3766666666666667 ,  average_token: 41.01, count:100
# average_f1_score: 0.555 ,  average_token: 74.41, count:100
# average_f1_score: 0.59 ,  average_token: 102.96, count:100
# average_f1_score: 0.425 ,  average_token: 122.38, count:100
# average_f1_score: 0.615 ,  average_token: 136.05, count:100
# average_f1_score: 0.565 ,  average_token: 114.98, count:100
# average_f1_score: 0.565 ,  average_token: 109.51, count:100
# average_f1_score: 0.575 ,  average_token: 82.82, count:100
# average_f1_score: 0.335 ,  average_token: 39.82, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 80.64, count:100
# average_f1_score: 0.515 ,  average_token: 123.57, count:100
# average_f1_score: 0.61 ,  average_token: 60.92, count:100
# average_f1_score: 0.585 ,  average_token: 79.38, count:100
# average_f1_score: 0.589 ,  average_token: 75.06, count:100
# average_f1_score: 0.565 ,  average_token: 83.01, count:100
# average_f1_score: 0.5 ,  average_token: 122.57, count:100
# average_f1_score: 0.42 ,  average_token: 149.52, count:100
# average_f1_score: 0.57 ,  average_token: 85.06, count:100
# average_f1_score: 0.515 ,  average_token: 101.06, count:100
# average_f1_score: 0.565 ,  average_token: 95.46, count:100
# average_f1_score: 0.425 ,  average_token: 147.58, count:100
# average_f1_score: 0.445 ,  average_token: 122.08, count:100
# average_f1_score: 0.515 ,  average_token: 117.38, count:100
# average_f1_score: 0.555 ,  average_token: 86.15, count:100
# average_f1_score: 0.595 ,  average_token: 70.03, count:100
# average_f1_score: 0.42 ,  average_token: 42.78, count:100
# average_f1_score: 0.61 ,  average_token: 81.04, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 79.28, count:100
# average_f1_score: 0.59 ,  average_token: 77.8, count:100
# average_f1_score: 0.57 ,  average_token: 95.49, count:100
# average_f1_score: 0.21 ,  average_token: 162.4, count:100
# average_f1_score: 0.6 ,  average_token: 48.87, count:100
# average_f1_score: 0.575 ,  average_token: 80.53, count:100
# average_f1_score: 0.66 ,  average_token: 52.5, count:100
# average_f1_score: 0.645 ,  average_token: 56.36, count:100
# average_f1_score: 0.6 ,  average_token: 77.54, count:100
# average_f1_score: 0.615 ,  average_token: 75.58, count:100
# average_f1_score: 0.535 ,  average_token: 93.35, count:100
# average_f1_score: 0.62 ,  average_token: 83.32, count:100
# average_f1_score: 0.595 ,  average_token: 47.88, count:100
# average_f1_score: 0.56 ,  average_token: 81.72, count:100
# average_f1_score: 0.565 ,  average_token: 100.86, count:100
# average_f1_score: 0.605 ,  average_token: 81.8, count:100
# average_f1_score: 0.575 ,  average_token: 111.39, count:100
# average_f1_score: 0.58 ,  average_token: 104.01, count:100
# average_f1_score: 0.585 ,  average_token: 49.13, count:100
# average_f1_score: 0.605 ,  average_token: 75.88, count:100
# average_f1_score: 0.575 ,  average_token: 101.82, count:100
# average_f1_score: 0.619 ,  average_token: 67.0, count:100
# average_f1_score: 0.595 ,  average_token: 65.39, count:100
# average_f1_score: 0.575 ,  average_token: 81.09, count:100
# average_f1_score: 0.565 ,  average_token: 57.17, count:100
# average_f1_score: 0.649 ,  average_token: 48.47, count:100
# average_f1_score: 0.585 ,  average_token: 48.7, count:100
# average_f1_score: 0.515 ,  average_token: 63.39, count:100
# average_f1_score: 0.575 ,  average_token: 80.94, count:100
# average_f1_score: 0.6 ,  average_token: 55.67, count:100
# average_f1_score: 0.384 ,  average_token: 165.12, count:100
# average_f1_score: 0.595 ,  average_token: 77.77, count:100
# average_f1_score: 0.475 ,  average_token: 119.52, count:100
# average_f1_score: 0.405 ,  average_token: 154.09, count:100
# average_f1_score: 0.66 ,  average_token: 61.39, count:100
# average_f1_score: 0.545 ,  average_token: 79.95, count:100
# average_f1_score: 0.635 ,  average_token: 73.92, count:100
# average_f1_score: 0.625 ,  average_token: 90.23, count:100
# average_f1_score: 0.52 ,  average_token: 52.56, count:100
# average_f1_score: 0.635 ,  average_token: 53.89, count:100
# average_f1_score: 0.605 ,  average_token: 116.37, count:100
# average_f1_score: 0.645 ,  average_token: 36.91, count:100
# average_f1_score: 0.445 ,  average_token: 145.57, count:100
# average_f1_score: 0.33 ,  average_token: 192.27, count:100
# average_f1_score: 0.619 ,  average_token: 57.68, count:100
# average_f1_score: 0.635 ,  average_token: 49.54, count:100
# average_f1_score: 0.595 ,  average_token: 95.92, count:100
# average_f1_score: 0.555 ,  average_token: 56.85, count:100
# average_f1_score: 0.519 ,  average_token: 81.77, count:100
# average_f1_score: 0.579 ,  average_token: 56.8, count:100
# average_f1_score: 0.57 ,  average_token: 84.87, count:100
# average_f1_score: 0.525 ,  average_token: 124.32, count:100
# average_f1_score: 0.605 ,  average_token: 51.54, count:100
# average_f1_score: 0.58 ,  average_token: 82.81, count:100
# average_f1_score: 0.22 ,  average_token: 18.0, count:100
# average_f1_score: 0.6 ,  average_token: 78.64, count:100
# average_f1_score: 0.635 ,  average_token: 53.34, count:100
# average_f1_score: 0.555 ,  average_token: 86.35, count:100
# average_f1_score: 0.64 ,  average_token: 68.98, count:100
# average_f1_score: 0.575 ,  average_token: 90.35, count:100
# average_f1_score: 0.605 ,  average_token: 92.33, count:100
# average_f1_score: 0.615 ,  average_token: 46.89, count:100
# average_f1_score: 0.625 ,  average_token: 47.69, count:100
# average_f1_score: 0.595 ,  average_token: 77.69, count:100
# average_f1_score: 0.645 ,  average_token: 50.41, count:100
# average_f1_score: 0.565 ,  average_token: 64.98, count:100
# average_f1_score: 0.59 ,  average_token: 74.85, count:100
# average_f1_score: 0.539 ,  average_token: 68.4, count:100
# average_f1_score: 0.614 ,  average_token: 66.29, count:100
# average_f1_score: 0.555 ,  average_token: 72.01, count:100
# average_f1_score: 0.56 ,  average_token: 87.2, count:100
# average_f1_score: 0.575 ,  average_token: 37.06, count:100
# average_f1_score: 0.619 ,  average_token: 46.95, count:100
# average_f1_score: 0.515 ,  average_token: 132.05, count:100
# average_f1_score: 0.59 ,  average_token: 70.53, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 86.37, count:100
# average_f1_score: 0.565 ,  average_token: 67.9, count:100
# average_f1_score: 0.265 ,  average_token: 134.8, count:100
# average_f1_score: 0.599 ,  average_token: 43.56, count:100
# average_f1_score: 0.535 ,  average_token: 114.56, count:100
# average_f1_score: 0.539 ,  average_token: 84.49, count:100
# average_f1_score: 0.525 ,  average_token: 145.82, count:100
# average_f1_score: 0.535 ,  average_token: 86.21, count:100
# average_f1_score: 0.635 ,  average_token: 86.41, count:100
# average_f1_score: 0.595 ,  average_token: 52.58, count:100
# average_f1_score: 0.61 ,  average_token: 104.07, count:100
# average_f1_score: 0.655 ,  average_token: 59.96, count:100
# average_f1_score: 0.505 ,  average_token: 100.63, count:100
# average_f1_score: 0.5 ,  average_token: 80.4, count:100
# average_f1_score: 0.515 ,  average_token: 126.19, count:100
# average_f1_score: 0.555 ,  average_token: 116.92, count:100
# average_f1_score: 0.565 ,  average_token: 80.76, count:100
# average_f1_score: 0.354 ,  average_token: 48.12, count:100
# average_f1_score: 0.62 ,  average_token: 60.39, count:100
# average_f1_score: 0.575 ,  average_token: 71.28, count:100
# average_f1_score: 0.5 ,  average_token: 120.65, count:100
# average_f1_score: 0.54 ,  average_token: 87.43, count:100
# average_f1_score: 0.525 ,  average_token: 86.85, count:100
# average_f1_score: 0.505 ,  average_token: 93.8, count:100
# average_f1_score: 0.605 ,  average_token: 90.48, count:100
# average_f1_score: 0.57 ,  average_token: 58.88, count:100
# average_f1_score: 0.505 ,  average_token: 150.79, count:100
# average_f1_score: 0.575 ,  average_token: 53.36, count:100
# average_f1_score: 0.515 ,  average_token: 129.0, count:100
# average_f1_score: 0.294 ,  average_token: 113.24, count:100
# average_f1_score: 0.595 ,  average_token: 102.13, count:100
# average_f1_score: 0.604 ,  average_token: 51.25, count:100
# average_f1_score: 0.595 ,  average_token: 66.23, count:100
# average_f1_score: 0.6 ,  average_token: 51.28, count:100
# average_f1_score: 0.539 ,  average_token: 89.55, count:100
# average_f1_score: 0.535 ,  average_token: 125.77, count:100
# average_f1_score: 0.545 ,  average_token: 88.31, count:100
# average_f1_score: 0.635 ,  average_token: 49.92, count:100
# average_f1_score: 0.505 ,  average_token: 123.29, count:100
# average_f1_score: 0.514 ,  average_token: 78.2, count:100
# average_f1_score: 0.535 ,  average_token: 129.28, count:100
# average_f1_score: 0.575 ,  average_token: 96.71, count:100
# average_f1_score: 0.6 ,  average_token: 93.07, count:100
# average_f1_score: 0.49 ,  average_token: 154.71, count:100
# average_f1_score: 0.565 ,  average_token: 70.79, count:100
# average_f1_score: 0.595 ,  average_token: 74.51, count:100
# average_f1_score: 0.509 ,  average_token: 83.73, count:100
# average_f1_score: 0.545 ,  average_token: 38.32, count:100
# average_f1_score: 0.569 ,  average_token: 84.64, count:100
# average_f1_score: 0.5 ,  average_token: 96.82, count:100
# average_f1_score: 0.595 ,  average_token: 60.95, count:100
# average_f1_score: 0.555 ,  average_token: 66.05, count:100
# average_f1_score: 0.585 ,  average_token: 86.33, count:100
# average_f1_score: 0.61 ,  average_token: 100.71, count:100
# average_f1_score: 0.409 ,  average_token: 78.5, count:100
# average_f1_score: 0.56 ,  average_token: 80.88, count:100
# average_f1_score: 0.545 ,  average_token: 72.51, count:100
# average_f1_score: 0.435 ,  average_token: 69.65, count:100
# average_f1_score: 0.555 ,  average_token: 74.34, count:100
# average_f1_score: 0.495 ,  average_token: 139.96, count:100
# average_f1_score: 0.605 ,  average_token: 66.35, count:100
# average_f1_score: 0.565 ,  average_token: 75.93, count:100
# average_f1_score: 0.245 ,  average_token: 80.72, count:100
# average_f1_score: 0.565 ,  average_token: 55.24, count:100
# average_f1_score: 0.625 ,  average_token: 99.84, count:100
# average_f1_score: 0.61 ,  average_token: 128.13, count:100
# average_f1_score: 0.515 ,  average_token: 130.65, count:100
# average_f1_score: 0.525 ,  average_token: 112.23, count:100
# average_f1_score: 0.495 ,  average_token: 123.29, count:100
# average_f1_score: 0.545 ,  average_token: 71.93, count:100
# average_f1_score: 0.585 ,  average_token: 64.42, count:100
# average_f1_score: 0.525 ,  average_token: 130.74, count:100
# average_f1_score: 0.625 ,  average_token: 86.3, count:100
# average_f1_score: 0.495 ,  average_token: 78.55, count:100
# average_f1_score: 0.575 ,  average_token: 62.94, count:100
# average_f1_score: 0.545 ,  average_token: 72.03, count:100
# average_f1_score: 0.53 ,  average_token: 88.04, count:100
# average_f1_score: 0.405 ,  average_token: 141.88, count:100
# average_f1_score: 0.545 ,  average_token: 59.99, count:100
# average_f1_score: 0.565 ,  average_token: 49.31, count:100
# average_f1_score: 0.535 ,  average_token: 65.67, count:100
# average_f1_score: 0.47 ,  average_token: 134.05, count:100
# average_f1_score: 0.39 ,  average_token: 151.03, count:100
# average_f1_score: 0.41 ,  average_token: 89.07, count:100
# average_f1_score: 0.635 ,  average_token: 51.34, count:100
# average_f1_score: 0.57 ,  average_token: 63.04, count:100
# average_f1_score: 0.57 ,  average_token: 71.63, count:100
# average_f1_score: 0.615 ,  average_token: 85.72, count:100
# average_f1_score: 0.555 ,  average_token: 79.35, count:100
# average_f1_score: 0.565 ,  average_token: 70.26, count:100
# average_f1_score: 0.084 ,  average_token: 172.26, count:100
# average_f1_score: 0.565 ,  average_token: 73.7, count:100
# average_f1_score: 0.589 ,  average_token: 105.72, count:100
# average_f1_score: 0.5589999999999999 ,  average_token: 67.93, count:100
# average_f1_score: 0.545 ,  average_token: 84.4, count:100
# average_f1_score: 0.605 ,  average_token: 81.89, count:100
# average_f1_score: 0.569 ,  average_token: 60.53, count:100
# average_f1_score: 0.605 ,  average_token: 66.28, count:100
# average_f1_score: 0.58 ,  average_token: 74.74, count:100
# average_f1_score: 0.505 ,  average_token: 70.19, count:100
# average_f1_score: 0.5489999999999999 ,  average_token: 59.58, count:100
#        id  best_100
# 0  1034.0     0.600
# 1  1043.0     0.620
# 2  1139.0     0.400
# 3  2065.0     0.645
# 4  2186.0     0.535

# %%
## 验证选择的能力

# %%
## 验证选择的能力
sorted_df =  df.sort_values(by="best_100", ascending=False).id.tolist()
# print(sorted_df)
selected_data = [int(i) for i in sorted_df]

print(len(selected_data))

# selected = {list(i.keys())[0] for i in sorted_data[:50] if list(i.keys())[0]!=0}
selected = selected_data[:1400]
selected_chosen_value = []
all_chosen_value = []
index_MATES = []
index_value = []
selected_distance = []
for i in range(Len):
    if i in selected:
    # print(f"{i}: {mean(chosen_value[i*1:(i+1)*1])}")
        t = mean(chosen_value_shuffled[i*5:(i+1)*5])
        selected_chosen_value.append(t)
        index_MATES += list(range(i*5,(i+1)*5))
    if i in selected_data:
        t = chosen_value_shuffled[i*5:(i+1)*5]
        all_chosen_value += t
        index_value += list(range(i*5,(i+1)*5))
        # selected_distance += mean(distance_shuffled[i*5:(i+1)*5])
        # print(f"{i}:{mean(chosen_value_shuffled[i*5:(i+1)*5])}")
print(mean(selected_chosen_value))
print(len(selected_chosen_value))
index_value = [index_value[x] for x in (np.argsort(all_chosen_value)[::-1][:len(selected_chosen_value)*5])]
print(len(index_value))
print(mean([all_chosen_value[x] for x in np.argsort(all_chosen_value)[::-1][:len(selected_chosen_value)*5]]))
# print(selected_distance/(len(selected)))
# Out:
# 2690
# 1.0498972789808658
# 1400
# 7000
# 1.1096404293695505

# %%
sorted_df =  df.sort_values(by="best_100", ascending=False).id.tolist()
# print(sorted_df)
selected_data = [int(i) for i in sorted_df]

min_val = df["best_100"].min()
max_val = df["best_100"].max()
normalize_df = df
normalize_df["best_100"] = (df["best_100"] - min_val)/(max_val - min_val)
print(normalize_df.sort_values(by="best_100", ascending=False).head())

mix_df = pd.DataFrame(columns=['id', 'mix_value', 'chosen_value'])
index_mix = []
selected_distance = []
for i in range(Len):
    if i in selected_data:
    # print(f"{i}: {mean(chosen_value[i*1:(i+1)*1])}")
        for t in range(i*5, (i+1)*5):
            mix_value = chosen_value_shuffled[t] + df.loc[df['id'] == i, 'best_100'].values[0]
            mix_df.loc[len(mix_df)] = [t, mix_value, chosen_value_shuffled[t]]
        
   
sorted_df =  mix_df.sort_values(by="mix_value", ascending=False)[:7000]
index_mix = sorted_df.id.tolist()
print(sorted_df['chosen_value'].mean())
# Out:
#           id  best_100
# 2081  2688.0  1.000000
# 1139  2096.0  0.994109
# 1141  2175.0  0.994109
# 1477   827.0  0.994109
# 1906  2367.0  0.994109
# 1.0897522448068582

# %%
sorted_df =  mix_df.sort_values(by="mix_value", ascending=False)[:10000]
index_mix_10K = sorted_df.id.tolist()
print(sorted_df['chosen_value'].mean())
print(len(index_mix_10K))
# Out:
# 1.0676400946471578
# 10000

# %%
import sys
sys.path.append("/home/wentaos/Optima/local_influence")

from my_utils import DataArguments, get_datasets

data_args = DataArguments(chat_template=None, dataset_mixer={'/data/user_data/wentaos/Optima/my_datasets/hotpot_qa_dpo_test_case20/iteration_0': 1.0}, text_column='text', dataset_splits=['train', 'test'], dataset_configs=None, preprocessing_num_workers=8, truncation_side=None, auto_insert_empty_system_msg=True)

###############
# Load datasets
###############
raw_datasets = get_datasets(
    data_args,
    splits=data_args.dataset_splits,
    configs=data_args.dataset_configs,
    columns_to_keep=[
        "messages",
        "chosen",
        "rejected",
        "prompt",
        "completion",
        "label",
    ],
    shuffle=True,
)
# Out:
# --------------------------
# Dataset({
#     features: ['chosen', 'rejected'],
#     num_rows: 18102
# })
# --------------------------
# --------------------------
# Dataset({
#     features: ['chosen', 'rejected'],
#     num_rows: 2012
# })
# --------------------------
# ------------------------------2-----------------

# %%
dataset_type = "cbt"

# %%
raw_datasets["train"] = raw_datasets["train"].select(index_MATES)
raw_datasets.save_to_disk(f"/data/user_data/wentaos/Optima/my_datasets/{dataset_type}_dpo_MATES_warmup_7K/iteration_0")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/7000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1603 [00:00<?, ? examples/s]

# %%
raw_datasets["train"] = raw_datasets["train"].select(index_value)
raw_datasets.save_to_disk(f"/data/user_data/wentaos/Optima/my_datasets/{dataset_type}_dpo_value_warmup_7K/iteration_0")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/7000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1603 [00:00<?, ? examples/s]

# %%
raw_datasets["train"] = raw_datasets["train"].select(index_mix_10K)
raw_datasets.save_to_disk(f"/data/user_data/wentaos/Optima/my_datasets/{dataset_type}_dpo_mix_warmup_10K/iteration_0")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2012 [00:00<?, ? examples/s]

# %%
index_random = list(range(len(raw_datasets["train"])))[:7000]
raw_datasets["train"] = raw_datasets["train"].select(index_random)
raw_datasets.save_to_disk(f"/data/user_data/wentaos/Optima/my_datasets/{dataset_type}_dpo_random_warmup_7K/iteration_0")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/7000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1603 [00:00<?, ? examples/s]
